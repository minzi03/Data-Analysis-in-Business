rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('RMSE:', rmse)

# MAPE
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print('MAPE:', mape)

# MSLE
msle = mean_squared_log_error(y_test, y_pred)
print('MSLE:', msle)
# Out:
# RMSE: 375.2402136066954
# MAPE: 8.243502064519035
# MSLE: 0.00933089595155446

# %%
# 10. Plotting
plt.plot(train_data.index, train_data, label='Train')
plt.plot(test_data.index, test_data, label='Test')
plt.plot(test_data.index, y_pred, label='Predict Test')
plt.plot(range(last_index + 1, last_index + 31), y_next_30_days, label='Next30Days')
plt.plot(range(last_index + 1, last_index + 61), y_next_60_days, label='Next60Days')
plt.plot(range(last_index + 1, last_index + 91), y_next_90_days, label='Next90Days')
plt.legend()
plt.show()

# %% [markdown]
# DHT Historical Data

# %%
# 1. Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error

# %%
# 2. Load data
df = pd.read_csv('DHT Historical Data.csv')
df = df['Price'].str.replace(',', '').astype(float)

df = df.dropna() # Drop missing values
df = df.sort_index(ascending=False)
df = df.reset_index(drop=True) # Reset the index

# %%
df
# Out:
# 0       10860.1
# 1       11224.9
# 2       11337.1
# 3       11561.6
# 4       11589.7
#          ...
# 1307    38600.0
# 1308    39300.0
# 1309    39500.0
# 1310    39300.0
# 1311    40400.0
# Name: Price, Length: 1312, dtype: float64

# %%
# 3. Split train, test
train_size = int(0.9 * len(df))
test_size = len(df) - train_size

train_data = df[:train_size]
test_data = df[train_size:]

# %%
# 4. Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data)

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# 5. Testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data)
y_pred = model.predict(x_test)

# %%
# 6. Create index predicts the next 30, 60, 90 days
last_index = df.index[-1]

# %%
x_next_30_days = np.array(range(last_index + 1, last_index + 31)).reshape(-1, 1)
x_next_60_days = np.array(range(last_index + 1, last_index + 61)).reshape(-1, 1)
x_next_90_days = np.array(range(last_index + 1, last_index + 91)).reshape(-1, 1)

# %%
# 7. Predictions for the next 30, 60 and 90 days
y_next_30_days = model.predict(x_next_30_days)
y_next_60_days = model.predict(x_next_60_days)
y_next_90_days = model.predict(x_next_90_days)

# %%
# 8. Price predictions for the next 30, 60 and 90 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
print('Predicted closing prices for the next 60 days:')
print(y_next_60_days)
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 30 days:
# [19108.87837312 19113.17167484 19117.46497656 19121.75827828
#  19126.05158    19130.34488172 19134.63818344 19138.93148516
#  19143.22478687 19147.51808859 19151.81139031 19156.10469203
#  19160.39799375 19164.69129547 19168.98459719 19173.2778989
#  19177.57120062 19181.86450234 19186.15780406 19190.45110578
#  19194.7444075  19199.03770922 19203.33101094 19207.62431265
#  19211.91761437 19216.21091609 19220.50421781 19224.79751953
#  19229.09082125 19233.38412297]
# Predicted closing prices for the next 60 days:
# [19108.87837312 19113.17167484 19117.46497656 19121.75827828
#  19126.05158    19130.34488172 19134.63818344 19138.93148516
#  19143.22478687 19147.51808859 19151.81139031 19156.10469203
#  19160.39799375 19164.69129547 19168.98459719 19173.2778989
#  19177.57120062 19181.86450234 19186.15780406 19190.45110578
#  19194.7444075  19199.03770922 19203.33101094 19207.62431265
#  19211.91761437 19216.21091609 19220.50421781 19224.79751953
#  19229.09082125 19233.38412297 19237.67742469 19241.9707264
#  19246.26402812 19250.55732984 19254.85063156 19259.14393328
#  19263.437235   19267.73053672 19272.02383844 19276.31714015
#  19280.61044187 19284.90374359 19289.19704531 19293.49034703
#  19297.78364875 19302.07695047 19306.37025218 19310.6635539
#  19314.95685562 19319.25015734 19323.54345906 19327.83676078
#  19332.1300625  19336.42336422 19340.71666593 19345.00996765
#  19349.30326937 19353.59657109 19357.88987281 19362.18317453]
# Predicted closing prices for the next 90 days:
# [19108.87837312 19113.17167484 19117.46497656 19121.75827828
#  19126.05158    19130.34488172 19134.63818344 19138.93148516
#  19143.22478687 19147.51808859 19151.81139031 19156.10469203
#  19160.39799375 19164.69129547 19168.98459719 19173.2778989
#  19177.57120062 19181.86450234 19186.15780406 19190.45110578
#  19194.7444075  19199.03770922 19203.33101094 19207.62431265
#  19211.91761437 19216.21091609 19220.50421781 19224.79751953
#  19229.09082125 19233.38412297 19237.67742469 19241.9707264
#  19246.26402812 19250.55732984 19254.85063156 19259.14393328
#  19263.437235   19267.73053672 19272.02383844 19276.31714015
#  19280.61044187 19284.90374359 19289.19704531 19293.49034703
#  19297.78364875 19302.07695047 19306.37025218 19310.6635539
#  19314.95685562 19319.25015734 19323.54345906 19327.83676078
#  19332.1300625  19336.42336422 19340.71666593 19345.00996765
#  19349.30326937 19353.59657109 19357.88987281 19362.18317453
#  19366.47647625 19370.76977797 19375.06307968 19379.3563814
#  19383.64968312 19387.94298484 19392.23628656 19396.52958828
#  19400.82289    19405.11619172 19409.40949343 19413.70279515
#  19417.99609687 19422.28939859 19426.58270031 19430.87600203
#  19435.16930375 19439.46260546 19443.75590718 19448.0492089
#  19452.34251062 19456.63581234 19460.92911406 19465.22241578
#  19469.5157175  19473.80901921 19478.10232093 19482.39562265
#  19486.68892437 19490.98222609]

# %%
# 9. Evaluation
# RMSE
rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('RMSE:', rmse)

# MAPE
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print('MAPE:', mape)

# MSLE
msle = mean_squared_log_error(y_test, y_pred)
print('MSLE:', msle)
# Out:
# RMSE: 8788.855475114478
# MAPE: 28.076169256432316
# MSLE: 0.13160423119238263

# %%
# 10. Plotting
plt.plot(train_data.index, train_data, label='Train')
plt.plot(test_data.index, test_data, label='Test')
plt.plot(test_data.index, y_pred, label='Predict Test')
plt.plot(range(last_index + 1, last_index + 31), y_next_30_days, label='Next30Days')
plt.plot(range(last_index + 1, last_index + 61), y_next_60_days, label='Next60Days')
plt.plot(range(last_index + 1, last_index + 91), y_next_90_days, label='Next90Days')
plt.legend()
plt.show()

# %% [markdown]
# DP3 Historical Data

# %%
# 1. Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error

# %%
# 2. Load data
df = pd.read_csv('DP3 Historical Data.csv')
df = df['Price'].str.replace(',', '').astype(float)

df = df.dropna() # Drop missing values
df = df.sort_index(ascending=False)
df = df.reset_index(drop=True) # Reset the index

# %%
df
# Out:
# 0       73800.0
# 1       74900.0
# 2       74400.0
# 3       74700.0
# 4       76300.0
#          ...
# 1132    60900.0
# 1133    61000.0
# 1134    61000.0
# 1135    61500.0
# 1136    61600.0
# Name: Price, Length: 1137, dtype: float64

# %%
# 3. Split train, test
train_size = int(0.9 * len(df))
test_size = len(df) - train_size

train_data = df[:train_size]
test_data = df[train_size:]

# %%
# 4. Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data)

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# 5. Testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data)
y_pred = model.predict(x_test)

# %%
# 6. Create index predicts the next 30, 60, 90 days
last_index = df.index[-1]

# %%
x_next_30_days = np.array(range(last_index + 1, last_index + 31)).reshape(-1, 1)
x_next_60_days = np.array(range(last_index + 1, last_index + 61)).reshape(-1, 1)
x_next_90_days = np.array(range(last_index + 1, last_index + 91)).reshape(-1, 1)

# %%
# 7. Predictions for the next 30, 60 and 90 days
y_next_30_days = model.predict(x_next_30_days)
y_next_60_days = model.predict(x_next_60_days)
y_next_90_days = model.predict(x_next_90_days)

# %%
# 8. Price predictions for the next 30, 60 and 90 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
print('Predicted closing prices for the next 60 days:')
print(y_next_60_days)
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 30 days:
# [60855.76059817 60834.02130805 60812.28201794 60790.54272783
#  60768.80343772 60747.06414761 60725.3248575  60703.58556739
#  60681.84627728 60660.10698717 60638.36769706 60616.62840695
#  60594.88911684 60573.14982673 60551.41053662 60529.67124651
#  60507.9319564  60486.19266629 60464.45337618 60442.71408607
#  60420.97479596 60399.23550585 60377.49621574 60355.75692563
#  60334.01763552 60312.27834541 60290.5390553  60268.79976519
#  60247.06047508 60225.32118497]
# Predicted closing prices for the next 60 days:
# [60855.76059817 60834.02130805 60812.28201794 60790.54272783
#  60768.80343772 60747.06414761 60725.3248575  60703.58556739
#  60681.84627728 60660.10698717 60638.36769706 60616.62840695
#  60594.88911684 60573.14982673 60551.41053662 60529.67124651
#  60507.9319564  60486.19266629 60464.45337618 60442.71408607
#  60420.97479596 60399.23550585 60377.49621574 60355.75692563
#  60334.01763552 60312.27834541 60290.5390553  60268.79976519
#  60247.06047508 60225.32118497 60203.58189486 60181.84260474
#  60160.10331463 60138.36402452 60116.62473441 60094.8854443
#  60073.14615419 60051.40686408 60029.66757397 60007.92828386
#  59986.18899375 59964.44970364 59942.71041353 59920.97112342
#  59899.23183331 59877.4925432  59855.75325309 59834.01396298
#  59812.27467287 59790.53538276 59768.79609265 59747.05680254
#  59725.31751243 59703.57822232 59681.83893221 59660.0996421
#  59638.36035199 59616.62106188 59594.88177177 59573.14248166]
# Predicted closing prices for the next 90 days:
# [60855.76059817 60834.02130805 60812.28201794 60790.54272783
#  60768.80343772 60747.06414761 60725.3248575  60703.58556739
#  60681.84627728 60660.10698717 60638.36769706 60616.62840695
#  60594.88911684 60573.14982673 60551.41053662 60529.67124651
#  60507.9319564  60486.19266629 60464.45337618 60442.71408607
#  60420.97479596 60399.23550585 60377.49621574 60355.75692563
#  60334.01763552 60312.27834541 60290.5390553  60268.79976519
#  60247.06047508 60225.32118497 60203.58189486 60181.84260474
#  60160.10331463 60138.36402452 60116.62473441 60094.8854443
#  60073.14615419 60051.40686408 60029.66757397 60007.92828386
#  59986.18899375 59964.44970364 59942.71041353 59920.97112342
#  59899.23183331 59877.4925432  59855.75325309 59834.01396298
#  59812.27467287 59790.53538276 59768.79609265 59747.05680254
#  59725.31751243 59703.57822232 59681.83893221 59660.0996421
#  59638.36035199 59616.62106188 59594.88177177 59573.14248166
#  59551.40319155 59529.66390143 59507.92461132 59486.18532121
#  59464.4460311  59442.70674099 59420.96745088 59399.22816077
#  59377.48887066 59355.74958055 59334.01029044 59312.27100033
#  59290.53171022 59268.79242011 59247.05313    59225.31383989
#  59203.57454978 59181.83525967 59160.09596956 59138.35667945
#  59116.61738934 59094.87809923 59073.13880912 59051.39951901
#  59029.6602289  59007.92093879 58986.18164868 58964.44235857
#  58942.70306846 58920.96377835]

# %%
# 9. Evaluation
# RMSE
rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('RMSE:', rmse)

# MAPE
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print('MAPE:', mape)

# MSLE
msle = mean_squared_log_error(y_test, y_pred)
print('MSLE:', msle)
# Out:
# RMSE: 5932.824108381621
# MAPE: 7.297039767029394
# MSLE: 0.008139034150688843

# %%
# 10. Plotting
plt.plot(train_data.index, train_data, label='Train')
plt.plot(test_data.index, test_data, label='Test')
plt.plot(test_data.index, y_pred, label='Predict Test')
plt.plot(range(last_index + 1, last_index + 31), y_next_30_days, label='Next30Days')
plt.plot(range(last_index + 1, last_index + 61), y_next_60_days, label='Next60Days')
plt.plot(range(last_index + 1, last_index + 91), y_next_90_days, label='Next90Days')
plt.legend()
plt.show()
