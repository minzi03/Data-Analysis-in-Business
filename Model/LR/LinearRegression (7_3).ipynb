# %% [markdown]
# AMV Historical Data

# %%
# 1. Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error

# %%
# 2. Load data
df = pd.read_csv('AMV Historical Data.csv')
df = df['Price'].str.replace(',', '').astype(float)

df = df.dropna() # Drop missing values
df = df.sort_index(ascending=False)
df = df.reset_index(drop=True) # Reset the index

# %%
df
# Out:
# 0       15225.0
# 1       14865.0
# 2       14414.0
# 3       14594.0
# 4       14144.0
#          ...
# 1308     3500.0
# 1309     3500.0
# 1310     3500.0
# 1311     3600.0
# 1312     3700.0
# Name: Price, Length: 1313, dtype: float64

# %%
# 3. Split train, test
train_size = int(0.7 * len(df))
test_size = len(df) - train_size

train_data = df[:train_size]
test_data = df[train_size:]

# %%
# 4. Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data)

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# 5. Testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data)
y_pred = model.predict(x_test)

# %%
# 6. Create index predicts the next 30, 60, 90 days
last_index = df.index[-1]

# %%
x_next_30_days = np.array(range(last_index + 1, last_index + 31)).reshape(-1, 1)
x_next_60_days = np.array(range(last_index + 1, last_index + 61)).reshape(-1, 1)
x_next_90_days = np.array(range(last_index + 1, last_index + 91)).reshape(-1, 1)

# %%
# 7. Predictions for the next 30, 60 and 90 days
y_next_30_days = model.predict(x_next_30_days)
y_next_60_days = model.predict(x_next_60_days)
y_next_90_days = model.predict(x_next_90_days)

# %%
# 8. Price predictions for the next 30, 60 and 90 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
print('Predicted closing prices for the next 60 days:')
print(y_next_60_days)
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 30 days:
# [7255.40218577 7247.74189879 7240.08161181 7232.42132482 7224.76103784
#  7217.10075086 7209.44046388 7201.78017689 7194.11988991 7186.45960293
#  7178.79931595 7171.13902896 7163.47874198 7155.818455   7148.15816802
#  7140.49788104 7132.83759405 7125.17730707 7117.51702009 7109.85673311
#  7102.19644612 7094.53615914 7086.87587216 7079.21558518 7071.55529819
#  7063.89501121 7056.23472423 7048.57443725 7040.91415026 7033.25386328]
# Predicted closing prices for the next 60 days:
# [7255.40218577 7247.74189879 7240.08161181 7232.42132482 7224.76103784
#  7217.10075086 7209.44046388 7201.78017689 7194.11988991 7186.45960293
#  7178.79931595 7171.13902896 7163.47874198 7155.818455   7148.15816802
#  7140.49788104 7132.83759405 7125.17730707 7117.51702009 7109.85673311
#  7102.19644612 7094.53615914 7086.87587216 7079.21558518 7071.55529819
#  7063.89501121 7056.23472423 7048.57443725 7040.91415026 7033.25386328
#  7025.5935763  7017.93328932 7010.27300233 7002.61271535 6994.95242837
#  6987.29214139 6979.6318544  6971.97156742 6964.31128044 6956.65099346
#  6948.99070647 6941.33041949 6933.67013251 6926.00984553 6918.34955854
#  6910.68927156 6903.02898458 6895.3686976  6887.70841061 6880.04812363
#  6872.38783665 6864.72754967 6857.06726268 6849.4069757  6841.74668872
#  6834.08640174 6826.42611476 6818.76582777 6811.10554079 6803.44525381]
# Predicted closing prices for the next 90 days:
# [7255.40218577 7247.74189879 7240.08161181 7232.42132482 7224.76103784
#  7217.10075086 7209.44046388 7201.78017689 7194.11988991 7186.45960293
#  7178.79931595 7171.13902896 7163.47874198 7155.818455   7148.15816802
#  7140.49788104 7132.83759405 7125.17730707 7117.51702009 7109.85673311
#  7102.19644612 7094.53615914 7086.87587216 7079.21558518 7071.55529819
#  7063.89501121 7056.23472423 7048.57443725 7040.91415026 7033.25386328
#  7025.5935763  7017.93328932 7010.27300233 7002.61271535 6994.95242837
#  6987.29214139 6979.6318544  6971.97156742 6964.31128044 6956.65099346
#  6948.99070647 6941.33041949 6933.67013251 6926.00984553 6918.34955854
#  6910.68927156 6903.02898458 6895.3686976  6887.70841061 6880.04812363
#  6872.38783665 6864.72754967 6857.06726268 6849.4069757  6841.74668872
#  6834.08640174 6826.42611476 6818.76582777 6811.10554079 6803.44525381
#  6795.78496683 6788.12467984 6780.46439286 6772.80410588 6765.1438189
#  6757.48353191 6749.82324493 6742.16295795 6734.50267097 6726.84238398
#  6719.182097   6711.52181002 6703.86152304 6696.20123605 6688.54094907
#  6680.88066209 6673.22037511 6665.56008812 6657.89980114 6650.23951416
#  6642.57922718 6634.91894019 6627.25865321 6619.59836623 6611.93807925
#  6604.27779226 6596.61750528 6588.9572183  6581.29693132 6573.63664433]

# %%
# 9. Evaluation
# RMSE
rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('RMSE:', rmse)

# MAPE
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print('MAPE:', mape)

# MSLE
msle = mean_squared_log_error(y_test, y_pred)
print('MSLE:', msle)
# Out:
# RMSE: 4816.310054828628
# MAPE: 120.01972959819524
# MSLE: 0.6261791064600772

# %%
# 10. Plotting
plt.plot(train_data.index, train_data, label='Train')
plt.plot(test_data.index, test_data, label='Test')
plt.plot(test_data.index, y_pred, label='Predict Test')
plt.plot(range(last_index + 1, last_index + 31), y_next_30_days, label='Next30Days')
plt.plot(range(last_index + 1, last_index + 61), y_next_60_days, label='Next60Days')
plt.plot(range(last_index + 1, last_index + 91), y_next_90_days, label='Next90Days')
plt.legend()
plt.show()

# %% [markdown]
# DHT Historical Data

# %%
# 1. Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error

# %%
# 2. Load data
df = pd.read_csv('DHT Historical Data.csv')
df = df['Price'].str.replace(',', '').astype(float)

df = df.dropna() # Drop missing values
df = df.sort_index(ascending=False)
df = df.reset_index(drop=True) # Reset the index

# %%
df
# Out:
# 0       10860.1
# 1       11224.9
# 2       11337.1
# 3       11561.6
# 4       11589.7
#          ...
# 1307    38600.0
# 1308    39300.0
# 1309    39500.0
# 1310    39300.0
# 1311    40400.0
# Name: Price, Length: 1312, dtype: float64

# %%
# 3. Split train, test
train_size = int(0.7 * len(df))
test_size = len(df) - train_size

train_data = df[:train_size]
test_data = df[train_size:]

# %%
# 4. Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data)

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# 5. Testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data)
y_pred = model.predict(x_test)

# %%
# 6. Create index predicts the next 30, 60, 90 days
last_index = df.index[-1]

# %%
x_next_30_days = np.array(range(last_index + 1, last_index + 31)).reshape(-1, 1)
x_next_60_days = np.array(range(last_index + 1, last_index + 61)).reshape(-1, 1)
x_next_90_days = np.array(range(last_index + 1, last_index + 91)).reshape(-1, 1)

# %%
# 7. Predictions for the next 30, 60 and 90 days
y_next_30_days = model.predict(x_next_30_days)
y_next_60_days = model.predict(x_next_60_days)
y_next_90_days = model.predict(x_next_90_days)

# %%
# 8. Price predictions for the next 30, 60 and 90 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
print('Predicted closing prices for the next 60 days:')
print(y_next_60_days)
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 30 days:
# [17019.59778871 17021.60858747 17023.61938623 17025.63018499
#  17027.64098376 17029.65178252 17031.66258128 17033.67338004
#  17035.6841788  17037.69497756 17039.70577633 17041.71657509
#  17043.72737385 17045.73817261 17047.74897137 17049.75977013
#  17051.77056889 17053.78136766 17055.79216642 17057.80296518
#  17059.81376394 17061.8245627  17063.83536146 17065.84616023
#  17067.85695899 17069.86775775 17071.87855651 17073.88935527
#  17075.90015403 17077.91095279]
# Predicted closing prices for the next 60 days:
# [17019.59778871 17021.60858747 17023.61938623 17025.63018499
#  17027.64098376 17029.65178252 17031.66258128 17033.67338004
#  17035.6841788  17037.69497756 17039.70577633 17041.71657509
#  17043.72737385 17045.73817261 17047.74897137 17049.75977013
#  17051.77056889 17053.78136766 17055.79216642 17057.80296518
#  17059.81376394 17061.8245627  17063.83536146 17065.84616023
#  17067.85695899 17069.86775775 17071.87855651 17073.88935527
#  17075.90015403 17077.91095279 17079.92175156 17081.93255032
#  17083.94334908 17085.95414784 17087.9649466  17089.97574536
#  17091.98654413 17093.99734289 17096.00814165 17098.01894041
#  17100.02973917 17102.04053793 17104.05133669 17106.06213546
#  17108.07293422 17110.08373298 17112.09453174 17114.1053305
#  17116.11612926 17118.12692802 17120.13772679 17122.14852555
#  17124.15932431 17126.17012307 17128.18092183 17130.19172059
#  17132.20251936 17134.21331812 17136.22411688 17138.23491564]
# Predicted closing prices for the next 90 days:
# [17019.59778871 17021.60858747 17023.61938623 17025.63018499
#  17027.64098376 17029.65178252 17031.66258128 17033.67338004
#  17035.6841788  17037.69497756 17039.70577633 17041.71657509
#  17043.72737385 17045.73817261 17047.74897137 17049.75977013
#  17051.77056889 17053.78136766 17055.79216642 17057.80296518
#  17059.81376394 17061.8245627  17063.83536146 17065.84616023
#  17067.85695899 17069.86775775 17071.87855651 17073.88935527
#  17075.90015403 17077.91095279 17079.92175156 17081.93255032
#  17083.94334908 17085.95414784 17087.9649466  17089.97574536
#  17091.98654413 17093.99734289 17096.00814165 17098.01894041
#  17100.02973917 17102.04053793 17104.05133669 17106.06213546
#  17108.07293422 17110.08373298 17112.09453174 17114.1053305
#  17116.11612926 17118.12692802 17120.13772679 17122.14852555
#  17124.15932431 17126.17012307 17128.18092183 17130.19172059
#  17132.20251936 17134.21331812 17136.22411688 17138.23491564
#  17140.2457144  17142.25651316 17144.26731192 17146.27811069
#  17148.28890945 17150.29970821 17152.31050697 17154.32130573
#  17156.33210449 17158.34290326 17160.35370202 17162.36450078
#  17164.37529954 17166.3860983  17168.39689706 17170.40769582
#  17172.41849459 17174.42929335 17176.44009211 17178.45089087
#  17180.46168963 17182.47248839 17184.48328716 17186.49408592
#  17188.50488468 17190.51568344 17192.5264822  17194.53728096
#  17196.54807972 17198.55887849]

# %%
# 9. Evaluation
# RMSE
rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('RMSE:', rmse)

# MAPE
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print('MAPE:', mape)

# MSLE
msle = mean_squared_log_error(y_test, y_pred)
print('MSLE:', msle)
# Out:
# RMSE: 7474.997902235852
# MAPE: 25.484304129611296
# MSLE: 0.11900040259354065

# %%
# 10. Plotting
plt.plot(train_data.index, train_data, label='Train')
plt.plot(test_data.index, test_data, label='Test')
plt.plot(test_data.index, y_pred, label='Predict Test')
plt.plot(range(last_index + 1, last_index + 31), y_next_30_days, label='Next30Days')
plt.plot(range(last_index + 1, last_index + 61), y_next_60_days, label='Next60Days')
plt.plot(range(last_index + 1, last_index + 91), y_next_90_days, label='Next90Days')
plt.legend()
plt.show()

# %% [markdown]
# DP3 Historical Data

# %%
# 1. Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_log_error

# %%
# 2. Load data
df = pd.read_csv('DP3 Historical Data.csv')
df = df['Price'].str.replace(',', '').astype(float)

df = df.dropna() # Drop missing values
df = df.sort_index(ascending=False)
df = df.reset_index(drop=True) # Reset the index

# %%
df
# Out:
# 0       73800.0
# 1       74900.0
# 2       74400.0
# 3       74700.0
# 4       76300.0
#          ...
# 1132    60900.0
# 1133    61000.0
# 1134    61000.0
# 1135    61500.0
# 1136    61600.0
# Name: Price, Length: 1137, dtype: float64

# %%
# 3. Split train, test
train_size = int(0.7 * len(df))
test_size = len(df) - train_size

train_data = df[:train_size]
test_data = df[train_size:]

# %%
# 4. Training
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data)

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# 5. Testing
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data)
y_pred = model.predict(x_test)

# %%
# 6. Create index predicts the next 30, 60, 90 days
last_index = df.index[-1]

# %%
x_next_30_days = np.array(range(last_index + 1, last_index + 31)).reshape(-1, 1)
x_next_60_days = np.array(range(last_index + 1, last_index + 61)).reshape(-1, 1)
x_next_90_days = np.array(range(last_index + 1, last_index + 91)).reshape(-1, 1)

# %%
# 7. Predictions for the next 30, 60 and 90 days
y_next_30_days = model.predict(x_next_30_days)
y_next_60_days = model.predict(x_next_60_days)
y_next_90_days = model.predict(x_next_90_days)

# %%
# 8. Price predictions for the next 30, 60 and 90 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
print('Predicted closing prices for the next 60 days:')
print(y_next_60_days)
print('Predicted closing prices for the next 90 days:')
print(y_next_90_days)
# Out:
# Predicted closing prices for the next 30 days:
#