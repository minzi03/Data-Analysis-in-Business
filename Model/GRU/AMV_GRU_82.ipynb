# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU

# %%
# 2. Đọc file csv và gắng index với giá Close
df = pd.read_csv('./AMV Historical Data.csv')
df['Price'] = df['Price'].str.replace(',', '').astype(float)
df1=df.reset_index()['Price']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100

time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Define GRU Model
model = Sequential()
model.add(GRU(64, input_shape=(time_step, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\khaqt\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 14s 294ms/step - loss: 0.1013 - val_loss: 0.0031
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0153 - val_loss: 6.2607e-04
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 207ms/step - loss: 0.0054 - val_loss: 2.2802e-04
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - loss: 0.0014 - val_loss: 3.1345e-04
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - loss: 0.0011 - val_loss: 2.1261e-04
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - loss: 0.0011 - val_loss: 2.2186e-04
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 9.6715e-04 - val_loss: 1.9609e-04
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - loss: 0.0011 - val_loss: 2.3407e-04
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 0.0016 - val_loss: 1.9967e-04
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - loss: 7.7179e-04 - val_loss: 1.8743e-04
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 0.0015 - val_loss: 1.9396e-04
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 0.0012 - val_loss: 2.3105e-04
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0014 - val_loss: 1.8127e-04
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 286ms/step - loss: 7.9491e-04 - val_loss: 1.7986e-04
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - loss: 8.7229e-04 - val_loss: 1.8145e-04
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - loss: 0.0011 - val_loss: 1.6959e-04
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 8.4675e-04 - val_loss: 1.7997e-04
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 7.8439e-04 - val_loss: 1.6568e-04
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 6.2464e-04 - val_loss: 2.1327e-04
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - loss: 6.8620e-04 - val_loss: 1.7759e-04
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - loss: 7.6337e-04 - val_loss: 1.7563e-04
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - loss: 0.0011 - val_loss: 1.6256e-04
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 6.2857e-04 - val_loss: 1.5634e-04
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - loss: 0.0011 - val_loss: 1.9431e-04
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 6.6788e-04 - val_loss: 1.5679e-04
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - loss: 7.3905e-04 - val_loss: 1.5174e-04
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.0013 - val_loss: 1.7115e-04
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 210ms/step - loss: 8.4386e-04 - val_loss: 1.5231e-04
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 8.0313e-04 - val_loss: 1.4830e-04
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - loss: 6.0574e-04 - val_loss: 1.4736e-04
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 249ms/step - loss: 4.8014e-04 - val_loss: 1.3640e-04
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 7.8090e-04 - val_loss: 1.2294e-04
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - loss: 5.5994e-04 - val_loss: 1.6323e-04
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - loss: 6.3087e-04 - val_loss: 1.1839e-04
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 212ms/step - loss: 4.2150e-04 - val_loss: 1.2041e-04
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 224ms/step - loss: 4.5594e-04 - val_loss: 1.1762e-04
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - loss: 5.3232e-04 - val_loss: 1.2349e-04
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - loss: 5.3662e-04 - val_loss: 1.2375e-04
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - loss: 5.0778e-04 - val_loss: 1.3716e-04
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 265ms/step - loss: 5.5122e-04 - val_loss: 2.2717e-04
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 253ms/step - loss: 7.0166e-04 - val_loss: 1.1905e-04
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - loss: 9.7884e-04 - val_loss: 1.6620e-04
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 259ms/step - loss: 7.7036e-04 - val_loss: 1.2518e-04
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 249ms/step - loss: 6.0639e-04 - val_loss: 1.2564e-04
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 264ms/step - loss: 8.8055e-04 - val_loss: 1.2337e-04
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 255ms/step - loss: 3.8002e-04 - val_loss: 1.4413e-04
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 235ms/step - loss: 6.8361e-04 - val_loss: 1.2688e-04
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 276ms/step - loss: 6.6151e-04 - val_loss: 1.5777e-04
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 253ms/step - loss: 4.3962e-04 - val_loss: 1.3735e-04
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - loss: 4.3884e-04 - val_loss: 1.1536e-04
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - loss: 4.1993e-04 - val_loss: 2.1870e-04
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 231ms/step - loss: 5.0854e-04 - val_loss: 1.4498e-04
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 266ms/step - loss: 4.2994e-04 - val_loss: 1.1320e-04
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 242ms/step - loss: 6.3978e-04 - val_loss: 1.5968e-04
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 273ms/step - loss: 6.9363e-04 - val_loss: 1.3290e-04
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 5.4258e-04 - val_loss: 1.1957e-04
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - loss: 9.0826e-04 - val_loss: 1.5490e-04
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - loss: 5.1931e-04 - val_loss: 1.1304e-04
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 6.5566e-04 - val_loss: 1.1488e-04

# %%
# 10. Dự báo dữ liệu test, val
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 103ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step

# %%
ytest_reshaped = ytest.reshape(-1, 1)

ytest_inverse = scaler.inverse_transform(ytest_reshaped)

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
train_predict=scaler.inverse_transform(train_predict)
y_pred=scaler.inverse_transform(y_pred)

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
test_rmse = np.sqrt(np.mean((y_pred - ytest_inverse)**2))
test_mape = np.mean(np.abs((ytest_inverse - y_pred) / ytest_inverse)) * 100
test_msle = np.mean((np.log1p(ytest_inverse) - np.log1p(y_pred)) ** 2)

print('Testing RMSE:', test_rmse)
print('Test MAPE', test_mape)
print('Test MSLE', test_msle )
# Out:
# Testing RMSE: 234.6080219491133
# Test MAPE 1.2412342824008842
# Test MSLE 0.00030838758174662643

# %%
# Predict next 30, 60, and 90 days
last_sequence_days = df1[-30:].reshape(1, 30, 1)
y_next_30_days = []
y_next_60_days = []
y_next_90_days = []

for i in range(90):
    next_day_pred = model.predict(last_sequence_days)
    if i < 30:
        y_next_30_days.append(next_day_pred[0][0])
    if i < 60:
        y_next_60_days.append(next_day_pred[0][0])
    y_next_90_days.append(next_day_pred[0][0])
    last_sequence_days = np.concatenate([last_sequence_days[:, 1:, :], next_day_pred.reshape(1, 1, 1)], axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 580ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 785ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 721ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step

# %%
# Inverse transform the predictions
y_next_30_days = scaler.inverse_transform(np.array(y_next_30_days).reshape(-1, 1)).flatten()
y_next_60_days = scaler.inverse_transform(np.array(y_next_60_days).reshape(-1, 1)).flatten()
y_next_90_days = scaler.inverse_transform(np.array(y_next_90_days).reshape(-1, 1)).flatten()

# %%
y_next_30_days
# Out:
# array([15113.755 , 15114.9795, 15080.632 , 15047.852 , 15016.    ,
#        14983.542 , 14950.27  , 14916.402 , 14882.086 , 14847.484 ,
#        14812.689 , 14777.808 , 14742.894 , 14708.019 , 14673.217 ,
#        14638.561 , 14604.087 , 14569.822 , 14535.8   , 14502.05  ,
#        14468.593 , 14435.452 , 14402.637 , 14370.163 , 14338.03  ,
#        14306.255 , 14274.829 , 14243.773 , 14213.07  , 14182.727 ],
#       dtype=float32)

# %%
# Print lengths
print("Length of y_next_30_days:", len(y_next_30_days))
print("Length of y_next_60_days:", len(y_next_60_days))
print("Length of y_next_90_days:", len(y_next_90_days))
# Out:
# Length of y_next_30_days: 30
# Length of y_next_60_days: 60
# Length of y_next_90_days: 90

# %%
# Create date ranges for next 30, 60, and 90 days
next_30_days_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+29, step=1)
next_60_days_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+59, step=1)
next_90_days_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+89, step=1)


# Plot the predictions
plt.figure(figsize=(12, 8))
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index,scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index,(y_pred))
plt.plot(next_30_days_index, y_next_30_days, label='Next 30 Days')
plt.plot(next_60_days_index, y_next_60_days, label='Next 60 Days')
plt.plot(next_90_days_index, y_next_90_days, label='Next 90 Days')
plt.legend()
plt.grid()
plt.title("Predictions for Next 30, 60, and 90 Days")
plt.xlabel("Date")
plt.ylabel("Price value")
plt.savefig('next_days_predictions.png')
plt.show()
