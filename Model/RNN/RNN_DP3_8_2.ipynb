# %% [markdown]
# ## Import the necessary libraries

# %%
import pandas as pd
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_squared_log_error
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('DP3 Historical Data.csv')
df.head(10)
# Out:
#          Date   Price    Open    High     Low    Vol. Change %
# 0  04/17/2024  68,000  68,000  68,300  68,000   8.91K    0.00%
# 1  04/16/2024  68,000  68,600  68,600  66,900  10.76K   -0.73%
# 2  04/15/2024  68,500  69,300  69,300  68,000  14.22K   -1.15%
# 3  04/12/2024  69,300  68,900  69,300  68,900   3.01K    0.58%
# 4  04/11/2024  68,900  69,500  69,500  68,200   5.36K   -0.86%
# 5  04/10/2024  69,500  69,500  69,500  69,500   2.30K    0.58%
# 6  04/09/2024  69,100  70,500  70,500  69,100   2.47K   -1.14%
# 7  04/08/2024  69,900  70,000  70,000  68,000   6.30K   -0.14%
# 8  04/05/2024  70,000  70,000  70,000  67,500  10.25K    0.00%
# 9  04/04/2024  70,000  70,400  70,700  70,000   2.80K   -0.57%

# %% [markdown]
# ## Data preprocessing

# %%
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Sort the data by date in ascending order
df = df.sort_values('Date')

# Set the 'Date' column as the index value
df.set_index('Date', inplace=True)
df = df.replace(',', '', regex=True)

# %%
# Show Dataframe
df
# Out:
#             Price   Open   High    Low    Vol. Change %
# Date
# 2019-01-02  85500  85000  92000  85000  12.70K    0.59%
# 2019-01-03  86500  85100  87900  85100   6.40K    1.17%
# 2019-01-04  87900  86700  88000  86600   4.87K    1.62%
# 2019-01-07  87900  86700  87900  86700   5.10K    0.00%
# 2019-01-08  91800  88000  92000  88000  19.40K    4.44%
# ...           ...    ...    ...    ...     ...      ...
# 2024-04-11  68900  69500  69500  68200   5.36K   -0.86%
# 2024-04-12  69300  68900  69300  68900   3.01K    0.58%
# 2024-04-15  68500  69300  69300  68000  14.22K   -1.15%
# 2024-04-16  68000  68600  68600  66900  10.76K   -0.73%
# 2024-04-17  68000  68000  68300  68000   8.91K    0.00%
#
# [1146 rows x 6 columns]

# %% [markdown]
# ## Scale Data

# %%
# Select 'Close' column
data = df['Price'].values

# %%
# Scale data
scaler = MinMaxScaler(feature_range=(0,1))
data_scaled = scaler.fit_transform(data.reshape(-1, 1))

# %% [markdown]
# ## Split the data into train, validation and test set with a ratio of 7 : 1 : 2

# %%
# Define the size of train, validation, test set
train_size = int(len(data_scaled) * 0.8)
val_size = int(len(data_scaled) * 0.1)
test_size = len(data_scaled) - train_size - val_size

# Split the data into train, test, and validation sets
train_data = data_scaled[:train_size]
val_data = data_scaled[train_size:train_size + val_size]
test_data = data_scaled[train_size + val_size:]

# %% [markdown]
# ## Create and add data into X, y

# %%
# Function to prepare data for LSTM
def add_data(data, sequence_length=60):
    X, Y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:(i + sequence_length), 0])
        Y.append(data[i + sequence_length, 0])
    return np.array(X), np.array(Y)

# %%
# Prepare sequences
sequence_length = 60
train_last_windowsize = train_data[-sequence_length:]
val_last_windowsize = val_data[-sequence_length:]

val_data_extended = np.concatenate((train_last_windowsize, val_data), axis=0)
test_data_extended = np.concatenate((val_last_windowsize, test_data), axis=0)

X_train, y_train = add_data(train_data, sequence_length)
X_val, y_val = add_data(val_data_extended, sequence_length)
X_test, y_test = add_data(test_data_extended, sequence_length)

# %%
# Reshape data for LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# ## Build Model

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# ## Training Model

# %%
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=32, verbose=2)
# Out:
# Epoch 1/50
# 27/27 - 13s - loss: 0.0262 - val_loss: 0.0644 - 13s/epoch - 487ms/step
# Epoch 2/50
# 27/27 - 3s - loss: 0.0061 - val_loss: 0.0660 - 3s/epoch - 106ms/step
# Epoch 3/50
# 27/27 - 3s - loss: 0.0055 - val_loss: 0.0569 - 3s/epoch - 105ms/step
# Epoch 4/50
# 27/27 - 3s - loss: 0.0050 - val_loss: 0.0514 - 3s/epoch - 106ms/step
# Epoch 5/50
# 27/27 - 5s - loss: 0.0047 - val_loss: 0.0462 - 5s/epoch - 169ms/step
# Epoch 6/50
# 27/27 - 3s - loss: 0.0046 - val_loss: 0.0405 - 3s/epoch - 107ms/step
# Epoch 7/50
# 27/27 - 3s - loss: 0.0049 - val_loss: 0.0459 - 3s/epoch - 107ms/step
# Epoch 8/50
# 27/27 - 3s - loss: 0.0040 - val_loss: 0.0425 - 3s/epoch - 105ms/step
# Epoch 9/50
# 27/27 - 4s - loss: 0.0040 - val_loss: 0.0363 - 4s/epoch - 152ms/step
# Epoch 10/50
# 27/27 - 3s - loss: 0.0035 - val_loss: 0.0391 - 3s/epoch - 113ms/step
# Epoch 11/50
# 27/27 - 3s - loss: 0.0034 - val_loss: 0.0337 - 3s/epoch - 106ms/step
# Epoch 12/50
# 27/27 - 3s - loss: 0.0037 - val_loss: 0.0374 - 3s/epoch - 105ms/step
# Epoch 13/50
# 27/27 - 4s - loss: 0.0038 - val_loss: 0.0286 - 4s/epoch - 134ms/step
# Epoch 14/50
# 27/27 - 4s - loss: 0.0036 - val_loss: 0.0298 - 4s/epoch - 138ms/step
# Epoch 15/50
# 27/27 - 3s - loss: 0.0034 - val_loss: 0.0279 - 3s/epoch - 107ms/step
# Epoch 16/50
# 27/27 - 3s - loss: 0.0029 - val_loss: 0.0268 - 3s/epoch - 107ms/step
# Epoch 17/50
# 27/27 - 3s - loss: 0.0029 - val_loss: 0.0256 - 3s/epoch - 121ms/step
# Epoch 18/50
# 27/27 - 4s - loss: 0.0029 - val_loss: 0.0272 - 4s/epoch - 150ms/step
# Epoch 19/50
# 27/27 - 3s - loss: 0.0027 - val_loss: 0.0238 - 3s/epoch - 105ms/step
# Epoch 20/50
# 27/27 - 3s - loss: 0.0027 - val_loss: 0.0245 - 3s/epoch - 106ms/step
# Epoch 21/50
# 27/27 - 3s - loss: 0.0027 - val_loss: 0.0237 - 3s/epoch - 105ms/step
# Epoch 22/50
# 27/27 - 4s - loss: 0.0028 - val_loss: 0.0230 - 4s/epoch - 158ms/step
# Epoch 23/50
# 27/27 - 3s - loss: 0.0029 - val_loss: 0.0250 - 3s/epoch - 105ms/step
# Epoch 24/50
# 27/27 - 3s - loss: 0.0026 - val_loss: 0.0229 - 3s/epoch - 103ms/step
# Epoch 25/50
# 27/27 - 3s - loss: 0.0024 - val_loss: 0.0215 - 3s/epoch - 106ms/step
# Epoch 26/50
# 27/27 - 4s - loss: 0.0024 - val_loss: 0.0214 - 4s/epoch - 154ms/step
# Epoch 27/50
# 27/27 - 3s - loss: 0.0026 - val_loss: 0.0210 - 3s/epoch - 111ms/step
# Epoch 28/50
# 27/27 - 3s - loss: 0.0023 - val_loss: 0.0208 - 3s/epoch - 107ms/step
# Epoch 29/50
# 27/27 - 3s - loss: 0.0025 - val_loss: 0.0212 - 3s/epoch - 104ms/step
# Epoch 30/50
# 27/27 - 4s - loss: 0.0026 - val_loss: 0.0202 - 4s/epoch - 136ms/step
# Epoch 31/50
# 27/27 - 4s - loss: 0.0021 - val_loss: 0.0197 - 4s/epoch - 134ms/step
# Epoch 32/50
# 27/27 - 3s - loss: 0.0023 - val_loss: 0.0216 - 3s/epoch - 108ms/step
# Epoch 33/50
# 27/27 - 3s - loss: 0.0029 - val_loss: 0.0194 - 3s/epoch - 106ms/step
# Epoch 34/50
# 27/27 - 3s - loss: 0.0025 - val_loss: 0.0186 - 3s/epoch - 123ms/step
# Epoch 35/50
# 27/27 - 4s - loss: 0.0022 - val_loss: 0.0187 - 4s/epoch - 152ms/step
# Epoch 36/50
# 27/27 - 3s - loss: 0.0022 - val_loss: 0.0187 - 3s/epoch - 104ms/step
# Epoch 37/50
# 27/27 - 3s - loss: 0.0020 - val_loss: 0.0190 - 3s/epoch - 106ms/step
# Epoch 38/50
# 27/27 - 3s - loss: 0.0021 - val_loss: 0.0192 - 3s/epoch - 105ms/step
# Epoch 39/50
# 27/27 - 4s - loss: 0.0022 - val_loss: 0.0188 - 4s/epoch - 159ms/step
# Epoch 40/50
# 27/27 - 3s - loss: 0.0022 - val_loss: 0.0179 - 3s/epoch - 104ms/step
# Epoch 41/50
# 27/27 - 3s - loss: 0.0024 - val_loss: 0.0180 - 3s/epoch - 104ms/step
# Epoch 42/50
# 27/27 - 3s - loss: 0.0024 - val_loss: 0.0186 - 3s/epoch - 109ms/step
# Epoch 43/50
# 27/27 - 4s - loss: 0.0022 - val_loss: 0.0187 - 4s/epoch - 153ms/step
# Epoch 44/50
# 27/27 - 3s - loss: 0.0019 - val_loss: 0.0186 - 3s/epoch - 111ms/step
# Epoch 45/50
# 27/27 - 3s - loss: 0.0023 - val_loss: 0.0176 - 3s/epoch - 107ms/step
# Epoch 46/50
# 27/27 - 3s - loss: 0.0027 - val_loss: 0.0181 - 3s/epoch - 105ms/step
# Epoch 47/50
# 27/27 - 4s - loss: 0.0023 - val_loss: 0.0179 - 4s/epoch - 132ms/step
# Epoch 48/50
# 27/27 - 4s - loss: 0.0020 - val_loss: 0.0175 - 4s/epoch - 134ms/step
# Epoch 49/50
# 27/27 - 3s - loss: 0.0020 - val_loss: 0.0185 - 3s/epoch - 104ms/step
# Epoch 50/50
# 27/27 - 3s - loss: 0.0021 - val_loss: 0.0173 - 3s/epoch - 103ms/step

# %% [markdown]
# ## Predict Close price in test and validation set

# %%
# Make predictions
y_pred = model.predict(X_test)
y_pred_val = model.predict(X_val)
# Out:
# 4/4 [==============================] - 3s 65ms/step
# 4/4 [==============================] - 0s 54ms/step

# %% [markdown]
# ## Transform data back to the original

# %%
# Inverse transform the predictions and actual values
y_pred = scaler.inverse_transform(y_pred)
y_val = scaler.inverse_transform(y_val.reshape(-1, 1))
y_pred_val = scaler.inverse_transform(y_pred_val)
train_data = scaler.inverse_transform(train_data)
test_data = scaler.inverse_transform(test_data)
val_data = scaler.inverse_transform(val_data)

# %% [markdown]
# ## Calculate the error of the model

# %%
# Calculate error metrics
test_mape = mean_absolute_percentage_error(y_test, y_pred)
test_mse = mean_squared_error(y_test, y_pred)
test_rmse = np.sqrt(test_mse)
test_msle = mean_squared_log_error(y_test, y_pred)

print(f"MAPE on Test set: {test_mape}")
print(f"RMSE on Test set: {test_rmse}")
print(f"MSLE on Test set: {test_msle}")
# Out:
# MAPE on Test set: 766187.104854657
# RMSE on Test set: 69279.12522170776
# MSLE on Test set: 121.87024560611366

# %%
# The error in validation set
val_mape = mean_absolute_percentage_error(y_val, y_pred_val)
val_mse = mean_squared_error(y_val, y_pred_val)
val_rmse = np.sqrt(val_mse)
val_msle = mean_squared_log_error(y_val, y_pred_val)

print(f"MAPE on Validate set: {val_mape}")
print(f"RMSE on Validate set: {val_rmse}")
print(f"MSLE on Validate set: {val_msle}")
# Out:
# MAPE on Validate set: 0.08087552059339725
# RMSE on Validate set: 13137.48196378689
# MSLE on Validate set: 0.017662888524423305

# %% [markdown]
# ## Predict Close price for 30 next days

# %%
last_sequence_days = data_scaled[-sequence_length:].reshape(1, -1, 1)
y_next_30_days = []

for i in range(30):
    next_day_pred = model.predict(last_sequence_days)
    y_next_30_days.append(next_day_pred[0][0])
    last_sequence_days = np.concatenate([last_sequence_days[:, 1:, :], next_day_pred.reshape(1, 1, 1)], axis=1)
# Out:
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
# Show the result of predict 30 next days
y_next_30_days = scaler.inverse_transform(np.array(y_next_30_days).reshape(-1, 1))
print(y_next_30_days.flatten())
# Out:
# [70092.38  69869.06  69747.945 69751.93  69867.85  70064.336 70307.63
#  70571.12  70838.234 71101.445 71359.21  71612.99  71865.08  72117.305
#  72370.734 72625.67  72881.98  73139.34  73397.5   73656.28  73915.66
#  74175.74  74436.66  74698.57  74961.664 75226.07  75491.94  75759.36
#  76028.45  76299.3  ]

# %% [markdown]
# ## Model visualization

# %%
# Plot the results
plt.figure(figsize=(12, 5))
plt.plot(df[:train_size].index, train_data)
plt.plot(df[train_size:train_size + val_size].index, val_data)
plt.plot(df[train_size:train_size + val_size].index, y_pred_val)
plt.plot(df[train_size + val_size:].index, test_data)
plt.plot(df[train_size + val_size:].index, y_pred)
plt.plot(pd.date_range(start=df.index[-1] + pd.DateOffset(days=1), periods=30), y_next_30_days)
plt.legend(['Train', 'Validate', 'Predict Validation', 'Test', 'Predict Test', 'Predict30days'])
plt.grid()
plt.title("DP3 Closing Price Data With Ratio 7_1_2")
plt.xlabel("Date")
plt.ylabel("Close value")
plt.savefig('RNN_712_DP3.png')
plt.show()
