# %% [markdown]
# ## Import the necessary libraries

# %%
import pandas as pd
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_squared_log_error
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('AMV Historical Data.csv')
df.head(10)
# Out:
#          Date    Price     Open     High      Low     Vol. Change %
# 0  04/17/2024  3,200.0  3,300.0  3,300.0  3,000.0    2.53M   -3.03%
# 1  04/16/2024  3,300.0  3,300.0  3,400.0  3,100.0    1.31M    0.00%
# 2  04/15/2024  3,300.0  3,500.0  3,600.0  3,300.0    1.28M   -5.71%
# 3  04/12/2024  3,500.0  3,500.0  3,600.0  3,500.0  840.38K    0.00%
# 4  04/11/2024  3,500.0  3,500.0  3,600.0  3,500.0  587.87K    0.00%
# 5  04/10/2024  3,500.0  3,500.0  3,600.0  3,500.0  324.14K    0.00%
# 6  04/09/2024  3,500.0  3,600.0  3,700.0  3,400.0    2.18M   -2.78%
# 7  04/08/2024  3,600.0  3,600.0  3,700.0  3,600.0  703.91K    0.00%
# 8  04/05/2024  3,600.0  3,700.0  3,700.0  3,500.0    3.40M   -5.26%
# 9  04/04/2024  3,800.0  3,800.0  3,900.0  3,700.0  867.30K    0.00%

# %% [markdown]
# ## Data preprocessing

# %%
# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Sort the data by date in ascending order
df = df.sort_values('Date')

# Set the 'Date' column as the index value
df.set_index('Date', inplace=True)
df = df.replace(',', '', regex=True)

# %%
# Show Dataframe
df
# Out:
#               Price     Open     High      Low     Vol. Change %
# Date
# 2019-01-02  17072.0  17071.7  17117.0  16936.5  181.74K   -0.26%
# 2019-01-03  16982.0  17026.6  17027.0  16215.8  259.31K   -0.53%
# 2019-01-04  16666.0  16666.3  16801.0  16576.2   86.63K   -1.86%
# 2019-01-07  16171.0  16576.2  16576.0  16080.7  102.90K   -2.97%
# 2019-01-08  16171.0  16260.9  16261.0  16080.7   33.59K    0.00%
# ...             ...      ...      ...      ...      ...      ...
# 2024-04-11   3500.0   3500.0   3600.0   3500.0  587.87K    0.00%
# 2024-04-12   3500.0   3500.0   3600.0   3500.0  840.38K    0.00%
# 2024-04-15   3300.0   3500.0   3600.0   3300.0    1.28M   -5.71%
# 2024-04-16   3300.0   3300.0   3400.0   3100.0    1.31M    0.00%
# 2024-04-17   3200.0   3300.0   3300.0   3000.0    2.53M   -3.03%
#
# [1322 rows x 6 columns]

# %% [markdown]
# ## Scale Data

# %%
# Select 'Close' column
data = df['Price'].values

# %%
# Scale data
scaler = MinMaxScaler(feature_range=(0,1))
data_scaled = scaler.fit_transform(data.reshape(-1, 1))

# %% [markdown]
# ## Split the data into train, validation and test set with a ratio of 7 : 1 : 2

# %%
# Define the size of train, validation, test set
train_size = int(len(data_scaled) * 0.8)
val_size = int(len(data_scaled) * 0.1)
test_size = len(data_scaled) - train_size - val_size

# Split the data into train, test, and validation sets
train_data = data_scaled[:train_size]
val_data = data_scaled[train_size:train_size + val_size]
test_data = data_scaled[train_size + val_size:]

# %% [markdown]
# ## Create and add data into X, y

# %%
# Function to prepare data for LSTM
def add_data(data, sequence_length=60):
    X, Y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:(i + sequence_length), 0])
        Y.append(data[i + sequence_length, 0])
    return np.array(X), np.array(Y)

# %%
# Prepare sequences
sequence_length = 60
train_last_windowsize = train_data[-sequence_length:]
val_last_windowsize = val_data[-sequence_length:]

val_data_extended = np.concatenate((train_last_windowsize, val_data), axis=0)
test_data_extended = np.concatenate((val_last_windowsize, test_data), axis=0)

X_train, y_train = add_data(train_data, sequence_length)
X_val, y_val = add_data(val_data_extended, sequence_length)
X_test, y_test = add_data(test_data_extended, sequence_length)

# %%
# Reshape data for LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# ## Build Model

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# ## Training Model

# %%
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=32, verbose=2)
# Out:
# Epoch 1/50
# 32/32 - 15s - loss: 0.0454 - val_loss: 0.0026 - 15s/epoch - 474ms/step
# Epoch 2/50
# 32/32 - 4s - loss: 0.0122 - val_loss: 3.3934e-04 - 4s/epoch - 128ms/step
# Epoch 3/50
# 32/32 - 5s - loss: 0.0110 - val_loss: 2.7370e-04 - 5s/epoch - 148ms/step
# Epoch 4/50
# 32/32 - 4s - loss: 0.0108 - val_loss: 6.0524e-04 - 4s/epoch - 117ms/step
# Epoch 5/50
# 32/32 - 4s - loss: 0.0094 - val_loss: 4.0628e-04 - 4s/epoch - 123ms/step
# Epoch 6/50
# 32/32 - 6s - loss: 0.0089 - val_loss: 0.0012 - 6s/epoch - 189ms/step
# Epoch 7/50
# 32/32 - 4s - loss: 0.0077 - val_loss: 2.6715e-04 - 4s/epoch - 114ms/step
# Epoch 8/50
# 32/32 - 4s - loss: 0.0080 - val_loss: 3.7600e-04 - 4s/epoch - 116ms/step
# Epoch 9/50
# 32/32 - 5s - loss: 0.0089 - val_loss: 2.9234e-04 - 5s/epoch - 165ms/step
# Epoch 10/50
# 32/32 - 4s - loss: 0.0067 - val_loss: 6.9155e-04 - 4s/epoch - 116ms/step
# Epoch 11/50
# 32/32 - 4s - loss: 0.0072 - val_loss: 3.2559e-04 - 4s/epoch - 114ms/step
# Epoch 12/50
# 32/32 - 5s - loss: 0.0064 - val_loss: 4.6112e-04 - 5s/epoch - 147ms/step
# Epoch 13/50
# 32/32 - 4s - loss: 0.0062 - val_loss: 4.7570e-04 - 4s/epoch - 130ms/step
# Epoch 14/50
# 32/32 - 4s - loss: 0.0058 - val_loss: 4.4153e-04 - 4s/epoch - 119ms/step
# Epoch 15/50
# 32/32 - 5s - loss: 0.0058 - val_loss: 3.4757e-04 - 5s/epoch - 151ms/step
# Epoch 16/50
# 32/32 - 4s - loss: 0.0059 - val_loss: 3.4973e-04 - 4s/epoch - 136ms/step
# Epoch 17/50
# 32/32 - 4s - loss: 0.0056 - val_loss: 3.3521e-04 - 4s/epoch - 115ms/step
# Epoch 18/50
# 32/32 - 4s - loss: 0.0049 - val_loss: 2.7664e-04 - 4s/epoch - 113ms/step
# Epoch 19/50
# 32/32 - 5s - loss: 0.0053 - val_loss: 2.3115e-04 - 5s/epoch - 163ms/step
# Epoch 20/50
# 32/32 - 4s - loss: 0.0054 - val_loss: 5.3282e-04 - 4s/epoch - 114ms/step
# Epoch 21/50
# 32/32 - 4s - loss: 0.0050 - val_loss: 1.6098e-04 - 4s/epoch - 115ms/step
# Epoch 22/50
# 32/32 - 5s - loss: 0.0046 - val_loss: 1.9416e-04 - 5s/epoch - 156ms/step
# Epoch 23/50
# 32/32 - 4s - loss: 0.0052 - val_loss: 2.7495e-04 - 4s/epoch - 120ms/step
# Epoch 24/50
# 32/32 - 4s - loss: 0.0052 - val_loss: 6.4687e-04 - 4s/epoch - 116ms/step
# Epoch 25/50
# 32/32 - 4s - loss: 0.0050 - val_loss: 1.6463e-04 - 4s/epoch - 132ms/step
# Epoch 26/50
# 32/32 - 5s - loss: 0.0053 - val_loss: 1.6920e-04 - 5s/epoch - 144ms/step
# Epoch 27/50
# 32/32 - 4s - loss: 0.0045 - val_loss: 2.3876e-04 - 4s/epoch - 127ms/step
# Epoch 28/50
# 32/32 - 4s - loss: 0.0042 - val_loss: 0.0012 - 4s/epoch - 115ms/step
# Epoch 29/50
# 32/32 - 5s - loss: 0.0038 - val_loss: 1.5917e-04 - 5s/epoch - 165ms/step
# Epoch 30/50
# 32/32 - 4s - loss: 0.0038 - val_loss: 1.1987e-04 - 4s/epoch - 117ms/step
# Epoch 31/50
# 32/32 - 4s - loss: 0.0037 - val_loss: 1.5439e-04 - 4s/epoch - 124ms/step
# Epoch 32/50
# 32/32 - 5s - loss: 0.0044 - val_loss: 3.7665e-04 - 5s/epoch - 163ms/step
# Epoch 33/50
# 32/32 - 4s - loss: 0.0041 - val_loss: 1.6813e-04 - 4s/epoch - 117ms/step
# Epoch 34/50
# 32/32 - 4s - loss: 0.0037 - val_loss: 2.0608e-04 - 4s/epoch - 118ms/step
# Epoch 35/50
# 32/32 - 5s - loss: 0.0040 - val_loss: 5.6351e-04 - 5s/epoch - 151ms/step
# Epoch 36/50
# 32/32 - 4s - loss: 0.0038 - val_loss: 1.1364e-04 - 4s/epoch - 122ms/step
# Epoch 37/50
# 32/32 - 5s - loss: 0.0040 - val_loss: 1.0194e-04 - 5s/epoch - 161ms/step
# Epoch 38/50
# 32/32 - 5s - loss: 0.0035 - val_loss: 6.2395e-04 - 5s/epoch - 160ms/step
# Epoch 39/50
# 32/32 - 4s - loss: 0.0037 - val_loss: 2.7376e-04 - 4s/epoch - 116ms/step
# Epoch 40/50
# 32/32 - 4s - loss: 0.0034 - val_loss: 4.3112e-04 - 4s/epoch - 128ms/step
# Epoch 41/50
# 32/32 - 5s - loss: 0.0033 - val_loss: 1.2220e-04 - 5s/epoch - 147ms/step
# Epoch 42/50
# 32/32 - 4s - loss: 0.0030 - val_loss: 5.1623e-04 - 4s/epoch - 135ms/step
# Epoch 43/50
# 32/32 - 4s - loss: 0.0034 - val_loss: 1.3257e-04 - 4s/epoch - 116ms/step
# Epoch 44/50
# 32/32 - 4s - loss: 0.0036 - val_loss: 2.5361e-04 - 4s/epoch - 118ms/step
# Epoch 45/50
# 32/32 - 5s - loss: 0.0031 - val_loss: 1.1467e-04 - 5s/epoch - 159ms/step
# Epoch 46/50
# 32/32 - 4s - loss: 0.0032 - val_loss: 9.0004e-05 - 4s/epoch - 114ms/step
# Epoch 47/50
# 32/32 - 4s - loss: 0.0033 - val_loss: 1.6653e-04 - 4s/epoch - 116ms/step
# Epoch 48/50
# 32/32 - 5s - loss: 0.0028 - val_loss: 1.0422e-04 - 5s/epoch - 165ms/step
# Epoch 49/50
# 32/32 - 4s - loss: 0.0031 - val_loss: 1.6852e-04 - 4s/epoch - 115ms/step
# Epoch 50/50
# 32/32 - 4s - loss: 0.0031 - val_loss: 1.6610e-04 - 4s/epoch - 113ms/step

# %% [markdown]
# ## Predict Close price in test and validation set

# %%
# Make predictions
y_pred = model.predict(X_test)
y_pred_val = model.predict(X_val)
# Out:
# 5/5 [==============================] - 2s 32ms/step
# 5/5 [==============================] - 0s 33ms/step

# %% [markdown]
# ## Transform data back to the original

# %%
# Inverse transform the predictions and actual values
y_pred = scaler.inverse_transform(y_pred)
y_val = scaler.inverse_transform(y_val.reshape(-1, 1))
y_pred_val = scaler.inverse_transform(y_pred_val)
train_data = scaler.inverse_transform(train_data)
test_data = scaler.inverse_transform(test_data)
val_data = scaler.inverse_transform(val_data)

# %% [markdown]
# ## Calculate the error of the model

# %%
# Calculate error metrics
test_mape = mean_absolute_percentage_error(y_test, y_pred)
test_mse = mean_squared_error(y_test, y_pred)
test_rmse = np.sqrt(test_mse)
test_msle = mean_squared_log_error(y_test, y_pred)

print(f"MAPE on Test set: {test_mape}")
print(f"RMSE on Test set: {test_rmse}")
print(f"MSLE on Test set: {test_msle}")
# Out:
# MAPE on Test set: 81178.85623198599
# RMSE on Test set: 4066.795966040654
# MSLE on Test set: 68.2295449171738

# %%
# The error in validation set
val_mape = mean_absolute_percentage_error(y_val, y_pred_val)
val_mse = mean_squared_error(y_val, y_pred_val)
val_rmse = np.sqrt(val_mse)
val_msle = mean_squared_log_error(y_val, y_pred_val)

print(f"MAPE on Validate set: {val_mape}")
print(f"RMSE on Validate set: {val_rmse}")
print(f"MSLE on Validate set: {val_msle}")
# Out:
# MAPE on Validate set: 0.04961237783632773
# RMSE on Validate set: 282.1034045653209
# MSLE on Validate set: 0.003610734547785294

# %% [markdown]
# ## Predict Close price for 30 next days

# %%
last_sequence_days = data_scaled[-sequence_length:].reshape(1, -1, 1)
y_next_30_days = []

for i in range(30):
    next_day_pred = model.predict(last_sequence_days)
    y_next_30_days.append(next_day_pred[0][0])
    last_sequence_days = np.concatenate([last_sequence_days[:, 1:, :], next_day_pred.reshape(1, 1, 1)], axis=1)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step

# %%
# Show the result of predict 30 next days
y_next_30_days = scaler.inverse_transform(np.array(y_next_30_days).reshape(-1, 1))
print(y_next_30_days.flatten())
# Out:
# [3674.711  3639.127  3629.7195 3647.4775 3685.9783 3736.6365 3792.2585
#  3848.3545 3902.9202 3955.5713 4006.6687 4056.726  4106.1255 4155.0586
#  4203.567  4251.6245 4299.1865 4346.2305 4392.755  4438.781  4484.338
#  4529.462  4574.189  4618.5474 4662.565  4706.2686 4749.681  4792.825
#  4835.721  4878.391 ]

# %% [markdown]
# ## Model visualization

# %%
# Plot the results
plt.figure(figsize=(12, 5))
plt.plot(df[:train_size].index, train_data)
plt.plot(df[train_size:train_size + val_size].index, val_data)
plt.plot(df[train_size:train_size + val_size].index, y_pred_val)
plt.plot(df[train_size + val_size:].index, test_data)
plt.plot(df[train_size + val_size:].index, y_pred)
plt.plot(pd.date_range(start=df.index[-1] + pd.DateOffset(days=1), periods=30), y_next_30_days)
plt.legend(['Train', 'Validate', 'Predict Validation', 'Test', 'Predict Test', 'Predict30days'])
plt.grid()
plt.title("AMV Closing Price Data With Ratio 7_1_2")
plt.xlabel("Date")
plt.ylabel("Close value")
plt.savefig('RNN_712_AMV.png')
plt.show()
